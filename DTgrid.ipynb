# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
para_grid = {'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
'max_features': ['none','sqrt','log2'],
'splitter':['best','random']}
grid=GridSearchCV(DecisionTreeRegressor(),para_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
pred=grid.predict(x_test)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 28 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'none' instead.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'none' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.59330045 0.50718328 0.57707984 0.56644858
#         nan        nan 0.65069299 0.55399327 0.60249301 0.51113437
#         nan        nan 0.59518039 0.59014429 0.64243415 0.59195657
#         nan        nan 0.62124188 0.60907735 0.6328978  0.59883147]
#   warnings.warn(

# %%
from sklearn.metrics import r2_score
rscore=r2_score(y_test,pred)
print("The r_score value for best parameters{}:".format(grid.best_params_),rscore)
# Out:
# The r_score value for best parameters{'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'}: 0.6789175895674208

# %%
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001258      0.000880         0.000000        0.000000
# 1        0.001893      0.000930         0.000000        0.000000
# 2        0.007052      0.001488         0.004885        0.000322
# 3        0.005962      0.000919         0.004016        0.001389
# 4        0.005964      0.002079         0.004688        0.001847
# 5        0.005912      0.001786         0.004810        0.002916
# 6        0.000937      0.000293         0.000000        0.000000
# 7        0.001110      0.000764         0.000000        0.000000
# 8        0.003999      0.000666         0.004242        0.000364
# 9        0.004006      0.001524         0.003503        0.001805
# 10       0.006731      0.001224         0.002707        0.001455
# 11       0.004344      0.000289         0.003795        0.000597
# 12       0.001430      0.001003         0.000000        0.000000
# 13       0.000595      0.000617         0.000000        0.000000
# 14       0.015055      0.003705         0.002525        0.001290
# 15       0.011464      0.002103         0.003579        0.004160
# 16       0.014097      0.003021         0.005479        0.004150
# 17       0.012173      0.003216         0.005528        0.003085
# 18       0.001224      0.000890         0.000000        0.000000
# 19       0.001033      0.001216         0.000000        0.000000
# 20       0.007519      0.003076         0.002719        0.001437
# 21       0.004450      0.002763         0.005224        0.003703
# 22       0.005571      0.000282         0.002506        0.001339
# 23       0.005518      0.001741         0.003034        0.001551
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               none           best
# 1    squared_error               none         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               none           best
# 7     friedman_mse               none         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               none           best
# 13  absolute_error               none         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               none           best
# 19         poisson               none         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.656921
# 3   {'criterion': 'squared_error', 'max_features':...           0.593433
# 4   {'criterion': 'squared_error', 'max_features':...           0.639150
# 5   {'criterion': 'squared_error', 'max_features':...           0.650116
# 6   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 7   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.729837
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.538146
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.786853
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.371086
# 12  {'criterion': 'absolute_error', 'max_features'...                NaN
# 13  {'criterion': 'absolute_error', 'max_features'...                NaN
# 14  {'criterion': 'absolute_error', 'max_features'...           0.554771
# 15  {'criterion': 'absolute_error', 'max_features'...           0.581367
# 16  {'criterion': 'absolute_error', 'max_features'...           0.684223
# 17  {'criterion': 'absolute_error', 'max_features'...           0.651591
# 18  {'criterion': 'poisson', 'max_features': 'none...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'none...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.543718
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.773147
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.626787
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.750428
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.586745           0.697016           0.666567
# 3            0.543250           0.394431           0.515318
# 4            0.427211           0.716464           0.600544
# 5            0.498069           0.693678           0.456492
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.614780           0.605540           0.713818
# 9            0.544240           0.540230           0.620834
# 10           0.585420           0.562021           0.419511
# 11           0.556271           0.613994           0.435984
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.639798           0.553102           0.672826
# 15           0.607922           0.677380           0.492049
# 16           0.643753           0.651765           0.583553
# 17           0.506359           0.715199           0.411166
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.674154           0.632089           0.557784
# 21           0.539929           0.616929           0.625074
# 22           0.562841           0.663193           0.691238
# 23           0.628448           0.674224           0.512919
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.359253         0.593300        0.122469                9
# 3            0.489485         0.507183        0.066079               16
# 4            0.502031         0.577080        0.101906               12
# 5            0.533888         0.566449        0.090569               13
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.589489         0.650693        0.058861                1
# 9            0.526517         0.553993        0.033936               14
# 10           0.658660         0.602493        0.120462                6
# 11           0.578336         0.511134        0.092081               15
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.555404         0.595180        0.051001                8
# 15           0.592003         0.590144        0.059379               11
# 16           0.648877         0.642434        0.032691                2
# 17           0.675468         0.591957        0.114657               10
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.698465         0.621242        0.061510                4
# 21           0.490307         0.609077        0.096046                5
# 22           0.620429         0.632898        0.043410                3
# 23           0.428137         0.598831        0.114944                7
